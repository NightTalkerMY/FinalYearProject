# %% [markdown]
# ## e2eET Skeleton Based HGR Using Data-Level Fusion (Modified by William)

# %%
import torch
print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
print(f"Device Name: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")
# Out:
# PyTorch Version: 2.1.2+cu121
# CUDA Available: True
# Device Name: NVIDIA GeForce RTX 4080 SUPER

# %%
from pathlib import Path
idx_gpu = 0

# %%
for d in sorted(Path("../splitted_datasets/").iterdir()):
    if d.is_dir(): print(f"{d=}: {len(list(d.rglob('*png')))}")
# Out:
# d=WindowsPath('../splitted_datasets/dataset_processed'): 3600

# %% [markdown]
# ---

# %%
## --- This is to train the datasets ---
dsName = "ds_own"
nClasses = 6
mVO_triplet = "custom top-down front-away"

# !python mVO.e2eEnsembleTuning.py -IG {idx_gpu} -nC {nClasses} -mVOs {mVO_triplet} -dsN {dsName} -IISE {0} -ISIS {"0"} -CEMC
# Out:
# c:\Users\wwon0076\Desktop\FYP\Gesture_System\venv\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\wwon0076\Desktop\FYP\Gesture_System\venv\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...
